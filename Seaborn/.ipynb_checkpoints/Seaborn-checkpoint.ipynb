# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\lokes\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %% [markdown]
# Common Plot Types in Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading a Dataset

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
print(tips.groupby('day')['tip'].mean())
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
# C:\Users\lokes\AppData\Local\Temp\ipykernel_2480\3086423591.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(tips.groupby('day')['tip'].mean())

# %% [markdown]
# Basic Plotting Functions

# %%
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
sns.lineplot(x='size', y='total_bill', data=tips)
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()

# %%
sns.histplot(data=tips, x='total_bill', bins=20)
plt.show()

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# Customizing Plots

# %% [markdown]
# Changing Color Palette:

# %%
sns.set_palette('husl')  # Set the color palette to 'husl'
sns.barplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# Adding Titles and Labels:

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.title('Total Bill by Day')
plt.xlabel('Day of the Week')
plt.ylabel('Total Bill ($)')
plt.show()

# %% [markdown]
# Setting Axes Limits:

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.ylim(0, 30)
plt.show()

# %% [markdown]
# Advanced Plotting with Seaborn

# %%
sns.pairplot(tips)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the tips dataset
tips = sns.load_dataset('tips')

# Select only the numeric columns for correlation
numeric_tips = tips.select_dtypes(include='number')

# Compute the correlation matrix
correlation_matrix = numeric_tips.corr()

# Plot the heatmap with annotations
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
g = sns.FacetGrid(tips, col='time')
g.map(plt.hist, 'total_bill')
plt.show()

# %%
sns.barplot(x='day', y='total_bill', data=tips)
plt.savefig('barplot.png')
plt.show()
